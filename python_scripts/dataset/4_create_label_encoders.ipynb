# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd '/gdrive/MyDrive/Colab Notebooks/WRI-Hackathon/python_scripts/dataset'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/Colab Notebooks/WRI-Hackathon/python_scripts/dataset

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import pickle

# %%
reservoir_df = pd.read_csv('reservoir_dataset.csv')
reservoir_df
# Out:
#         FLOW_DATE  RESERVOIR  PRESENT_STORAGE_TMC  ... DATE  DAY  SEASON
# 0      2011-01-01  Hemavathi                31.60  ...    1    0  WINTER
# 1      2012-01-01  Hemavathi                12.48  ...    1    0  WINTER
# 2      2014-01-01  Hemavathi                11.64  ...    1    0  WINTER
# 3      2015-01-01  Hemavathi                24.04  ...    1    0  WINTER
# 4      2016-01-01  Hemavathi                 6.23  ...    1    0  WINTER
# ...           ...        ...                  ...  ...  ...  ...     ...
# 13237  2015-12-31      K.R.S                28.01  ...   31  364  WINTER
# 13238  2016-12-31      K.R.S                10.56  ...   31  364  WINTER
# 13239  2017-12-31      K.R.S                25.83  ...   31  364  WINTER
# 13240  2018-12-31      K.R.S                36.61  ...   31  364  WINTER
# 13241  2019-12-31      K.R.S                45.16  ...   31  364  WINTER
#
# [13242 rows x 11 columns]

# %%
month_date_day_season_df = reservoir_df[['MONTH', 'DATE', 'DAY', 'SEASON']].drop_duplicates()
month_date_day_season_df
# Out:
#        MONTH  DATE  DAY  SEASON
# 0          1     1    0  WINTER
# 36         1     2    1  WINTER
# 68         1     3    2  WINTER
# 100        1     4    3  WINTER
# 132        1     5    4  WINTER
# ...      ...   ...  ...     ...
# 13062     12    27  360  WINTER
# 13098     12    28  361  WINTER
# 13134     12    29  362  WINTER
# 13170     12    30  363  WINTER
# 13206     12    31  364  WINTER
#
# [366 rows x 4 columns]

# %%
month_le = LabelEncoder().fit(month_date_day_season_df['MONTH'].unique())
# day_le = LabelEncoder().fit(month_date_day_season_df['DAY'].unique())
season_le = LabelEncoder().fit(month_date_day_season_df['SEASON'].unique())
date_le = LabelEncoder().fit(month_date_day_season_df['DATE'].unique())

# %%
with open('month_le.pkl', 'wb') as f:
    pickle.dump(month_le, f)

# with open('day_le.pkl', 'wb') as f:
#     pickle.dump(day_le, f)

with open('season_le.pkl', 'wb') as f:
    pickle.dump(season_le, f)

with open('date_le.pkl', 'wb') as f:
    pickle.dump(date_le, f)

# month_date_day_season_df.to_csv('month_date_day_season.csv', index=False)
